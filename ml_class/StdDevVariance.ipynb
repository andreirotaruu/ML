# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(10.0, 5.0, 1000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# np.float64(4.977317418756197)

# %%
incomes.var()
# Out:
# np.float64(24.77368868705385)
